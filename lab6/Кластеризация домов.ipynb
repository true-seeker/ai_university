# %% [markdown]
# ### Чтение исходных данных.

# %%
import pandas
df = pandas.read_csv("kc_house_data.csv")
df
# Out:
#                id             date     price  bedrooms  bathrooms  \
# 0      7129300520  20141013T000000  221900.0         3       1.00
# 1      6414100192  20141209T000000  538000.0         3       2.25
# 2      5631500400  20150225T000000  180000.0         2       1.00
# 3      2487200875  20141209T000000  604000.0         4       3.00
# 4      1954400510  20150218T000000  510000.0         3       2.00
# ...           ...              ...       ...       ...        ...
# 21608   263000018  20140521T000000  360000.0         3       2.50
# 21609  6600060120  20150223T000000  400000.0         4       2.50
# 21610  1523300141  20140623T000000  402101.0         2       0.75
# 21611   291310100  20150116T000000  400000.0         3       2.50
# 21612  1523300157  20141015T000000  325000.0         2       0.75
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  grade  \
# 0             1180      5650     1.0           0     0  ...      7
# 1             2570      7242     2.0           0     0  ...      7
# 2              770     10000     1.0           0     0  ...      6
# 3             1960      5000     1.0           0     0  ...      7
# 4             1680      8080     1.0           0     0  ...      8
# ...            ...       ...     ...         ...   ...  ...    ...
# 21608         1530      1131     3.0           0     0  ...      8
# 21609         2310      5813     2.0           0     0  ...      8
# 21610         1020      1350     2.0           0     0  ...      7
# 21611         1600      2388     2.0           0     0  ...      8
# 21612         1020      1076     2.0           0     0  ...      7
#
#        sqft_above  sqft_basement  yr_built  yr_renovated  zipcode      lat  \
# 0            1180              0      1955             0    98178  47.5112
# 1            2170            400      1951          1991    98125  47.7210
# 2             770              0      1933             0    98028  47.7379
# 3            1050            910      1965             0    98136  47.5208
# 4            1680              0      1987             0    98074  47.6168
# ...           ...            ...       ...           ...      ...      ...
# 21608        1530              0      2009             0    98103  47.6993
# 21609        2310              0      2014             0    98146  47.5107
# 21610        1020              0      2009             0    98144  47.5944
# 21611        1600              0      2004             0    98027  47.5345
# 21612        1020              0      2008             0    98144  47.5941
#
#           long  sqft_living15  sqft_lot15
# 0     -122.257           1340        5650
# 1     -122.319           1690        7639
# 2     -122.233           2720        8062
# 3     -122.393           1360        5000
# 4     -122.045           1800        7503
# ...        ...            ...         ...
# 21608 -122.346           1530        1509
# 21609 -122.362           1830        7200
# 21610 -122.299           1020        2007
# 21611 -122.069           1410        1287
# 21612 -122.299           1020        1357
#
# [21613 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21613 entries, 0 to 21612
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21613 non-null  int64
#  1   date           21613 non-null  object
#  2   price          21613 non-null  float64
#  3   bedrooms       21613 non-null  int64
#  4   bathrooms      21613 non-null  float64
#  5   sqft_living    21613 non-null  int64
#  6   sqft_lot       21613 non-null  int64
#  7   floors         21613 non-null  float64
#  8   waterfront     21613 non-null  int64
#  9   view           21613 non-null  int64
#  10  condition      21613 non-null  int64
#  11  grade          21613 non-null  int64
#  12  sqft_above     21613 non-null  int64
#  13  sqft_basement  21613 non-null  int64
#  14  yr_built       21613 non-null  int64
#  15  yr_renovated   21613 non-null  int64
#  16  zipcode        21613 non-null  int64
#  17  lat            21613 non-null  float64
#  18  long           21613 non-null  float64
#  19  sqft_living15  21613 non-null  int64
#  20  sqft_lot15     21613 non-null  int64
# dtypes: float64(5), int64(15), object(1)
# memory usage: 3.5+ MB

# %%
df.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
taglist = ['sqft_living',
       'sqft_lot', 'floors', 'waterfront', 'view', 'condition','yr_built', 'yr_renovated', 'zipcode',
       'lat', 'long', 'sqft_lot15']
X = df[taglist]
y = df['price']

# %%
X.head()
# Out:
#    sqft_living  sqft_lot  floors  waterfront  view  condition  yr_built  \
# 0         1180      5650     1.0           0     0          3      1955
# 1         2570      7242     2.0           0     0          3      1951
# 2          770     10000     1.0           0     0          3      1933
# 3         1960      5000     1.0           0     0          5      1965
# 4         1680      8080     1.0           0     0          3      1987
#
#    yr_renovated  zipcode      lat     long  sqft_lot15
# 0             0    98178  47.5112 -122.257        5650
# 1          1991    98125  47.7210 -122.319        7639
# 2             0    98028  47.7379 -122.233        8062
# 3             0    98136  47.5208 -122.393        5000
# 4             0    98074  47.6168 -122.045        7503

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn import *
tree_model = tree.DecisionTreeClassifier(max_depth=10)
tree_model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=10)

# %%
import numpy as np
from sklearn.ensemble import RandomForestRegressor
from catboost import CatBoostRegressor

rf = RandomForestRegressor(random_state=0)
cb = CatBoostRegressor()

rf.fit(X_train,y_train)
cb.fit(X_train,y_train)

predict_rf = rf.predict(X_test)
predict_cb = cb.predict(X_test)

# %%
claster_tags=f.columns
claster_tags=taglist+['price']

# %%
from sklearn.cluster import DBSCAN, KMeans
t = 20 #Перебор количества кластеров
# создадим пустой список для записи показателя WCSS (нашей ошибки)
wcss = []
X= df[claster_tags]
for i in range(1, t):
    
    kmeans = KMeans(n_clusters = i, init = 'k-means++', max_iter = 2000, n_init = 10, random_state = 42)
    kmeans.fit(X)
 
    # для каждого кластера рассчитаем ошибку (атрибут inertia_) и поместим в список
    wcss.append(kmeans.inertia_)

# %%
wcss
# Out:
# [2966129517245568.5,
#  1407650988667124.8,
#  783141108120665.0,
#  513530459524122.7,
#  376835116619939.6,
#  290226825194204.2,
#  232077766736803.22,
#  188332671313452.84,
#  162821570593768.7,
#  139860943119539.83,
#  120581228423807.36,
#  106194764205300.67,
#  95950941589257.33,
#  85759975584631.03,
#  78704152168557.72,
#  72183906465196.8,
#  67461149798916.31,
#  62387321648163.73,
#  57972352708718.48]

# %%
import matplotlib.pyplot as plt

# зададим размер график
plt.figure(figsize = (10,6))
# передадим функции plot() последовательность кластеров и ошибку WCSS
plt.plot(range(1, t), wcss)
# и добавим подписи
plt.title('Выбор количества кластеров методом локтя')
plt.xlabel('Количество кластеров')
plt.ylabel('WCSS')
# Out:
# Text(0, 0.5, 'WCSS')

# %%
from sklearn.metrics import silhouette_score, davies_bouldin_score,v_measure_score

# %%
km_scores= []
km_silhouette = []
vmeasure_score =[]
db_score = []
X_scaled=X.copy()
for i in range(2,t):
    km = KMeans(n_clusters=i, random_state=0).fit(X_scaled)
    preds = km.predict(X_scaled)
    
    print("Score for number of cluster(s) {}: {}".format(i,km.score(X_scaled)))
    km_scores.append(-km.score(X_scaled))
    
    silhouette = silhouette_score(X_scaled,preds)
    km_silhouette.append(silhouette)
    print("Silhouette score for number of cluster(s) {}: {}".format(i,silhouette))
    
    db = davies_bouldin_score(X_scaled,preds)
    db_score.append(db)
    print("Davies Bouldin score for number of cluster(s) {}: {}".format(i,db))
    
#    v_measure = v_measure_score(y,preds)
#    vmeasure_score.append(v_measure)
#    print("V-measure score for number of cluster(s) {}: {}".format(i,v_measure))
    print("-"*100)
# Out:
# Score for number of cluster(s) 2: -1408118606403274.8
# Silhouette score for number of cluster(s) 2: 0.7255475552906111
# Davies Bouldin score for number of cluster(s) 2: 0.5829394116075884
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 3: -783142026025446.4
# Silhouette score for number of cluster(s) 3: 0.5934572883316184
# Davies Bouldin score for number of cluster(s) 3: 0.578427160785513
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 4: -513530728911986.0
# Silhouette score for number of cluster(s) 4: 0.5737165847293586
# Davies Bouldin score for number of cluster(s) 4: 0.5647857220896991
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 5: -376847762736789.56
# Silhouette score for number of cluster(s) 5: 0.5314740182879633
# Davies Bouldin score for number of cluster(s) 5: 0.5784230170919799
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 6: -290226825194204.1
# Silhouette score for number of cluster(s) 6: 0.5323151647437742
# Davies Bouldin score for number of cluster(s) 6: 0.5373208754425253
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 7: -231766725077316.03
# Silhouette score for number of cluster(s) 7: 0.5144643858963572
# Davies Bouldin score for number of cluster(s) 7: 0.5617093305916532
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 8: -188328150251341.03
# Silhouette score for number of cluster(s) 8: 0.500695188171298
# Davies Bouldin score for number of cluster(s) 8: 0.5686277912091944
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 9: -162851678173554.25
# Silhouette score for number of cluster(s) 9: 0.5010531836858912
# Davies Bouldin score for number of cluster(s) 9: 0.5621818392092679
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 10: -139865747890071.83
# Silhouette score for number of cluster(s) 10: 0.4880982847797992
# Davies Bouldin score for number of cluster(s) 10: 0.5787408705488792
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 11: -120544898113154.34
# Silhouette score for number of cluster(s) 11: 0.4971559607988925
# Davies Bouldin score for number of cluster(s) 11: 0.6084235746048515
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 12: -106041624688801.33
# Silhouette score for number of cluster(s) 12: 0.48562761509306723
# Davies Bouldin score for number of cluster(s) 12: 0.6074995431014821
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 13: -96528085068432.45
# Silhouette score for number of cluster(s) 13: 0.4778753144773694
# Davies Bouldin score for number of cluster(s) 13: 0.6089251176270836
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 14: -85918850898160.28
# Silhouette score for number of cluster(s) 14: 0.4824066666608741
# Davies Bouldin score for number of cluster(s) 14: 0.5813269944926149
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 15: -78914793765381.81
# Silhouette score for number of cluster(s) 15: 0.48104265076138053
# Davies Bouldin score for number of cluster(s) 15: 0.5944211279833578
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 16: -72452945162910.78
# Silhouette score for number of cluster(s) 16: 0.48084435704279455
# Davies Bouldin score for number of cluster(s) 16: 0.6197285457008233
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 17: -67202196844402.07
# Silhouette score for number of cluster(s) 17: 0.4632955191558753
# Davies Bouldin score for number of cluster(s) 17: 0.6074869814132978
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 18: -62231057484799.06
# Silhouette score for number of cluster(s) 18: 0.46552241494372365
# Davies Bouldin score for number of cluster(s) 18: 0.6261801925375472
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 19: -58088837636475.51
# Silhouette score for number of cluster(s) 19: 0.46517615697498815
# Davies Bouldin score for number of cluster(s) 19: 0.6196824318135019
# ----------------------------------------------------------------------------------------------------

# %%
plt.figure(figsize=(7,4))
plt.title("The elbow method for determining number of clusters\n",fontsize=16)
plt.scatter(x=[i for i in range(2,t)],y=km_scores,s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Number of clusters",fontsize=14)
plt.ylabel("K-means score",fontsize=15)
plt.xticks([i for i in range(2,t)],fontsize=14)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.figure(figsize=(7,4))
plt.title("The silhouette coefficient method \nfor determining number of clusters\n",fontsize=16)
plt.scatter(x=[i for i in range(2,t)],y=km_silhouette,s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Number of clusters",fontsize=14)
plt.ylabel("Silhouette score",fontsize=15)
plt.xticks([i for i in range(2,t)],fontsize=10)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.scatter(x=[i for i in range(2,t)],y=db_score,s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Davies-Bouldin score")
plt.show()

# %%
from sklearn.mixture import GaussianMixture
gm_bic= []
gm_score=[]
for i in range(2,t):
    gm = GaussianMixture(n_components=i,n_init=10,tol=1e-3,max_iter=2000).fit(X_scaled)
    print("BIC for number of cluster(s) {}: {}".format(i,gm.bic(X_scaled)))
    print("Log-likelihood score for number of cluster(s) {}: {}".format(i,gm.score(X_scaled)))
    print("-"*100)
    gm_bic.append(-gm.bic(X_scaled))
    gm_score.append(gm.score(X_scaled))

# %%
import numpy as np

plt.figure(figsize=(7,4))
plt.title("The Gaussian Mixture model BIC \nfor determining number of clusters\n",fontsize=16)
plt.scatter(x=[i for i in range(2,t)],y=np.log(np.abs(gm_bic)),s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Number of clusters",fontsize=14)
plt.ylabel("Log of Gaussian mixture BIC score",fontsize=15)
plt.xticks([i for i in range(2,t)],fontsize=14)
plt.yticks(fontsize=15)
plt.show()

# %%
model_cluster_6 = KMeans(6)
model_cluster_6.fit(X_scaled)
y_pred_km_6 = model_cluster_6.predict(X_scaled)

# %%
model_cluster_13 = KMeans(13)
model_cluster_13.fit(X_scaled)
y_pred_km_13 = model_cluster_13.predict(X_scaled)

# %%
x6 = X_scaled['sqft_living']
y6 = X_scaled['price']
plt.figure(figsize=(20,10))
plt.title("Визуализация кластеров\n",fontsize=16)
plt.scatter(x=x6,y=y6,s=15,c=y_pred_km_6)
plt.grid(True)
plt.xlabel("Жилая площадь",fontsize=14)
plt.ylabel("Стоимость",fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=15)
plt.show()

# %%
x6 = X_scaled['sqft_lot']
y6 = X_scaled['price']
plt.figure(figsize=(20,10))
plt.title("Визуализация кластеров\n",fontsize=16)
plt.scatter(x=x6,y=y6,s=15,c=y_pred_km_6)
plt.grid(True)
plt.xlabel("Общая площадь",fontsize=14)
plt.ylabel("Стоимость",fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=15)
plt.show()

# %%
x13= X_scaled['sqft_lot']
y13 = X_scaled['price']
plt.figure(figsize=(20,10))
plt.title("Визуализация кластеров\n",fontsize=16)
plt.scatter(x=x13,y=y13,s=15,c=y_pred_km_13)
plt.grid(True)
plt.xlabel("Общая площадь",fontsize=14)
plt.ylabel("Стоимость",fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=15)
plt.show()

# %%
model_dbscan = DBSCAN(eps=10000, min_samples=100)

y_pred_dbscan = model_dbscan.fit_predict(X_scaled)

# %%
xdbs= X_scaled['sqft_living']
ydbs = X_scaled['price']
plt.figure(figsize=(20,10))
plt.title("Визуализация кластеров\n",fontsize=16)
plt.scatter(x=xdbs,y=ydbs,s=15,c=y_pred_dbscan)
plt.grid(True)
plt.xlabel("Жилая площадь",fontsize=14)
plt.ylabel("Стоимость",fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=15)
plt.show()

# %%
#Здесь фактическое шкалирование
from sklearn.preprocessing import MinMaxScaler
mms = {}
dfs = X_scaled.copy(deep=True)
for c in X_scaled.columns:
    mms[c] = MinMaxScaler().fit(dfs[c].values.reshape(-1,1))
    dfs[c] = mms[c].transform(dfs[c].values.reshape(-1,1))

# %%
dfs
# Out:
#        sqft_living  sqft_lot  floors  waterfront  view  condition  yr_built  \
# 0         0.067170  0.003108     0.0         0.0   0.0        0.5  0.478261
# 1         0.172075  0.004072     0.4         0.0   0.0        0.5  0.443478
# 2         0.036226  0.005743     0.0         0.0   0.0        0.5  0.286957
# 3         0.126038  0.002714     0.0         0.0   0.0        1.0  0.565217
# 4         0.104906  0.004579     0.0         0.0   0.0        0.5  0.756522
# ...            ...       ...     ...         ...   ...        ...       ...
# 21608     0.093585  0.000370     0.8         0.0   0.0        0.5  0.947826
# 21609     0.152453  0.003206     0.4         0.0   0.0        0.5  0.991304
# 21610     0.055094  0.000503     0.4         0.0   0.0        0.5  0.947826
# 21611     0.098868  0.001132     0.4         0.0   0.0        0.5  0.904348
# 21612     0.055094  0.000337     0.4         0.0   0.0        0.5  0.939130
#
#        yr_renovated   zipcode       lat      long  sqft_lot15     price
# 0          0.000000  0.893939  0.571498  0.217608    0.005742  0.019266
# 1          0.988089  0.626263  0.908959  0.166113    0.008027  0.060721
# 2          0.000000  0.136364  0.936143  0.237542    0.008513  0.013770
# 3          0.000000  0.681818  0.586939  0.104651    0.004996  0.069377
# 4          0.000000  0.368687  0.741354  0.393688    0.007871  0.057049
# ...             ...       ...       ...       ...         ...       ...
# 21608      0.000000  0.515152  0.874055  0.143688    0.000986  0.037377
# 21609      0.000000  0.732323  0.570693  0.130399    0.007523  0.042623
# 21610      0.000000  0.722222  0.705324  0.182724    0.001558  0.042898
# 21611      0.000000  0.131313  0.608975  0.373754    0.000731  0.042623
# 21612      0.000000  0.722222  0.704842  0.182724    0.000811  0.032787
#
# [21613 rows x 13 columns]

# %%
model_cluster_6 = KMeans(6)
model_cluster_6.fit(dfs)
y_pred_km_6 = model_cluster_6.predict(dfs)
dfs['Кластер'] = kmeans.labels_

# %%
x6 = dfs['sqft_living']
y6 = dfs['price']
plt.figure(figsize=(20,10))
plt.title("Визуализация кластеров\n",fontsize=16)
plt.scatter(x=y6,y=x6,s=15,c=y_pred_km_6)
plt.grid(True)
plt.xlabel("Стоимость",fontsize=14)
plt.ylabel("Кластер",fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=15)
plt.show()

# %%
dfs.loc[dfs['Кластер']==0].describe()
# Out:
#        sqft_living     sqft_lot       floors   waterfront         view  \
# count  3529.000000  3529.000000  3529.000000  3529.000000  3529.000000
# mean      0.098316     0.005556     0.140606     0.000567     0.013106
# std       0.035868     0.007624     0.197570     0.023803     0.084526
# min       0.006038     0.000031     0.000000     0.000000     0.000000
# 25%       0.073208     0.003264     0.000000     0.000000     0.000000
# 50%       0.097358     0.004349     0.000000     0.000000     0.000000
# 75%       0.121509     0.005552     0.400000     0.000000     0.000000
# max       0.241509     0.126868     0.800000     1.000000     1.000000
#
#          condition     yr_built  yr_renovated      zipcode          lat  \
# count  3529.000000  3529.000000   3529.000000  3529.000000  3529.000000
# mean      0.600808     0.623611      0.024084     0.369089     0.481844
# std       0.158785     0.219240      0.152414     0.289856     0.224459
# min       0.000000     0.000000      0.000000     0.000000     0.032974
# 25%       0.500000     0.478261      0.000000     0.146465     0.317999
# 50%       0.500000     0.634783      0.000000     0.272727     0.457938
# 75%       0.750000     0.800000      0.000000     0.590909     0.591765
# max       1.000000     0.991304      1.000000     1.000000     0.999839
#
#               long   sqft_lot15        price  Кластер
# count  3529.000000  3529.000000  3529.000000   3529.0
# mean      0.249188     0.009922     0.027048      0.0
# std       0.111919     0.013612     0.003160      0.0
# min       0.005814     0.000000     0.021613      0.0
# 25%       0.162791     0.006144     0.024262      0.0
# 50%       0.226744     0.008113     0.026885      0.0
# 75%       0.295681     0.009902     0.029508      0.0
# max       0.996678     0.307983     0.032525      0.0

# %%
model_dbscan_s = DBSCAN(eps=0.0001, min_samples=100)
y_pred_dbscan_s = model_dbscan_s.fit_predict(dfs)

# %%
model_dbscan_s.get_params()
# Out:
# {'algorithm': 'auto',
#  'eps': 0.0001,
#  'leaf_size': 30,
#  'metric': 'euclidean',
#  'metric_params': None,
#  'min_samples': 100,
#  'n_jobs': None,
#  'p': None}

# %%
xdbs= dfs['sqft_living']
ydbs = dfs['price']
plt.figure(figsize=(20,10))
plt.title("Визуализация кластеров\n",fontsize=16)
plt.scatter(x=xdbs,y=ydbs,s=15,c=y_pred_dbscan_s)
plt.grid(True)
plt.xlabel("Жилая площадь",fontsize=14)
plt.ylabel("Стоимость",fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=15)
plt.show()

# %%
km_scores= []
km_silhouette = []
vmeasure_score =[]
db_score = []

for i in range(2,t):
    km = KMeans(n_clusters=i, random_state=0).fit(dfs)
    preds = km.predict(dfs)
    
    print("Score for number of cluster(s) {}: {}".format(i,km.score(dfs)))
    km_scores.append(-km.score(dfs))
    
    silhouette = silhouette_score(dfs,preds)
    km_silhouette.append(silhouette)
    print("Silhouette score for number of cluster(s) {}: {}".format(i,silhouette))
    
    db = davies_bouldin_score(dfs,preds)
    db_score.append(db)
    print("Davies Bouldin score for number of cluster(s) {}: {}".format(i,db))
    
#    v_measure = v_measure_score(y,preds)
#    vmeasure_score.append(v_measure)
#    print("V-measure score for number of cluster(s) {}: {}".format(i,v_measure))
    print("-"*100)
# Out:
# Score for number of cluster(s) 2: -176330.82735126588
# Silhouette score for number of cluster(s) 2: 0.654396061437726
# Davies Bouldin score for number of cluster(s) 2: 0.4916869944151233
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 3: -55148.406033800886
# Silhouette score for number of cluster(s) 3: 0.6740441932409781
# Davies Bouldin score for number of cluster(s) 3: 0.48228779154953205
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 4: -34629.011394700865
# Silhouette score for number of cluster(s) 4: 0.6529571403439655
# Davies Bouldin score for number of cluster(s) 4: 0.4134793465593291
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 5: -19746.513625034488
# Silhouette score for number of cluster(s) 5: 0.6895693696030065
# Davies Bouldin score for number of cluster(s) 5: 0.42160457610855834
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 6: -12035.297865725459
# Silhouette score for number of cluster(s) 6: 0.6544181754885217
# Davies Bouldin score for number of cluster(s) 6: 0.5006573997952698
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 7: -10810.091319797246
# Silhouette score for number of cluster(s) 7: 0.5976771090186193
# Davies Bouldin score for number of cluster(s) 7: 0.6611768955229165
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 8: -9683.284280610957
# Silhouette score for number of cluster(s) 8: 0.5913848790789119
# Davies Bouldin score for number of cluster(s) 8: 0.6907361771586971
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 9: -9405.327976373184
# Silhouette score for number of cluster(s) 9: 0.549693473962331
# Davies Bouldin score for number of cluster(s) 9: 0.8472934835738943
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 10: -8536.501014447582
# Silhouette score for number of cluster(s) 10: 0.4667860722874045
# Davies Bouldin score for number of cluster(s) 10: 1.0258743707138513
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 11: -8014.439562532635
# Silhouette score for number of cluster(s) 11: 0.4518650499882976
# Davies Bouldin score for number of cluster(s) 11: 1.0686380059315566
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 12: -7737.937132775305
# Silhouette score for number of cluster(s) 12: 0.45660483274788377
# Davies Bouldin score for number of cluster(s) 12: 1.0345437517059317
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 13: -7439.786133729889
# Silhouette score for number of cluster(s) 13: 0.3566351980670096
# Davies Bouldin score for number of cluster(s) 13: 1.2328511600754253
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 14: -7079.024382066857
# Silhouette score for number of cluster(s) 14: 0.38330705634770845
# Davies Bouldin score for number of cluster(s) 14: 1.1109042628613133
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 15: -6816.798061008252
# Silhouette score for number of cluster(s) 15: 0.37087733197023437
# Davies Bouldin score for number of cluster(s) 15: 1.1294962037308642
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 16: -6525.779577154883
# Silhouette score for number of cluster(s) 16: 0.33671403510563086
# Davies Bouldin score for number of cluster(s) 16: 1.186239855102134
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 17: -6256.2225353452695
# Silhouette score for number of cluster(s) 17: 0.32930171401528013
# Davies Bouldin score for number of cluster(s) 17: 1.2487511139173038
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 18: -6160.265287778234
# Silhouette score for number of cluster(s) 18: 0.3283281892185143
# Davies Bouldin score for number of cluster(s) 18: 1.2188276219461287
# ----------------------------------------------------------------------------------------------------
# Score for number of cluster(s) 19: -5853.194766388729
# Silhouette score for number of cluster(s) 19: 0.32951726719136176
# Davies Bouldin score for number of cluster(s) 19: 1.1893784487560115
# ----------------------------------------------------------------------------------------------------

# %%
plt.figure(figsize=(7,4))
plt.title("The elbow method for determining number of clusters\n",fontsize=16)
plt.scatter(x=[i for i in range(2,t)],y=km_scores,s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Number of clusters",fontsize=14)
plt.ylabel("K-means score",fontsize=15)
plt.xticks([i for i in range(2,t)],fontsize=14)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.figure(figsize=(7,4))
plt.title("The silhouette coefficient method \nfor determining number of clusters\n",fontsize=16)
plt.scatter(x=[i for i in range(2,t)],y=km_silhouette,s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Number of clusters",fontsize=14)
plt.ylabel("Silhouette score",fontsize=15)
plt.xticks([i for i in range(2,t)],fontsize=10)
plt.yticks(fontsize=15)
plt.show()

# %%
plt.scatter(x=[i for i in range(2,t)],y=db_score,s=150,edgecolor='k')
plt.grid(True)
plt.xlabel("Davies-Bouldin score")
plt.show()

# %%
model_cluster_8 = KMeans(8)
model_cluster_8.fit(dfs)
y_pred_km_8 = model_cluster_8.predict(dfs)

# %%
model_cluster_8.cluster_centers_
# Out:
# array([[1.93058740e-01, 8.72328382e-03, 2.81109185e-01, 1.90641248e-02,
#         1.29838244e-01, 6.12940497e-01, 6.39951775e-01, 7.27699389e-02,
#         3.59502010e-01, 7.50763616e-01, 2.68295936e-01, 1.31021904e-02,
#         1.06846628e-01, 1.11322935e+00],
#        [1.78404562e-01, 7.56398993e-03, 2.62210629e-01, 1.46723182e-02,
#         1.00423867e-01, 6.17215520e-01, 6.15449171e-01, 5.79250340e-02,
#         3.86456676e-01, 7.52587578e-01, 2.59799148e-01, 1.25988039e-02,
#         9.69802647e-02, 9.29116400e+00],
#        [1.37589396e-01, 1.55112922e-02, 2.11084665e-01, 3.06018361e-03,
#         5.21081265e-02, 6.01411085e-01, 6.15436926e-01, 3.83563262e-02,
#         3.86206506e-01, 7.23850492e-01, 2.64979537e-01, 2.41597793e-02,
#         6.20284097e-02, 1.50720843e+01],
#        [1.24157372e-01, 5.87966476e-03, 1.97517644e-01, 5.84083719e-03,
#         4.73351180e-02, 5.90289608e-01, 6.40210778e-01, 3.46941622e-02,
#         4.20571006e-01, 6.46857138e-01, 2.43490507e-01, 1.03958358e-02,
#         5.07513454e-02, 5.89948893e+00],
#        [1.24815400e-01, 5.87876998e-03, 1.94848046e-01, 7.23589001e-03,
#         3.90014472e-02, 5.95586107e-01, 6.20610332e-01, 3.52255335e-02,
#         4.03115087e-01, 7.32366717e-01, 2.51968835e-01, 1.00533114e-02,
#         5.59210421e-02, 3.01649783e+00],
#        [1.03625375e-01, 6.54270876e-03, 1.07660283e-01, 4.16319734e-03,
#         4.56910908e-02, 6.10220649e-01, 5.41657315e-01, 4.20152354e-02,
#         3.84906517e-01, 4.84895435e-01, 2.38185717e-01, 1.12076423e-02,
#         3.98717160e-02, 1.72094088e+01],
#        [2.54259372e-01, 7.19317328e-02, 3.22427441e-01, 3.95778364e-02,
#         2.50000000e-01, 5.98284960e-01, 6.93105426e-01, 1.02115401e-01,
#         2.82695024e-01, 6.86256893e-01, 3.00322583e-01, 7.67190610e-02,
#         1.59643199e-01, 1.32506596e+01],
#        [9.83157343e-02, 5.55642072e-03, 1.40606404e-01, 5.66732785e-04,
#         1.31056957e-02, 6.00807594e-01, 6.23610581e-01, 2.40837527e-02,
#         3.69089020e-01, 4.81843744e-01, 2.49188264e-01, 9.92238762e-03,
#         2.70478532e-02, 2.93098879e-14]])

# %%
x13= dfs['sqft_living']
y13 = dfs['price']
plt.figure(figsize=(20,10))
plt.title("Визуализация кластеров\n",fontsize=16)
plt.scatter(x=x13,y=y13,s=15,c=y_pred_km_8)
plt.grid(True)
plt.xlabel("Жилая площадь",fontsize=14)
plt.ylabel("Стоимость",fontsize=15)
plt.xticks(fontsize=14)
plt.yticks(fontsize=15)
plt.show()

# %% [markdown]
# Далее - обратное преобразование к обычному масштабу координат центров кластеров.
